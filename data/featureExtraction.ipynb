# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import spicy
import sys
import os
import pickle
import librosa
import librosa.display
from IPython.display import Audio
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d

# %% [markdown]
# # We will extract all the features for all the genres and their songs

# %%
# Directories containing the audio files for different genres
genre_dirs = ['./rawData/rock/', './rawData/pop/', './rawData/arabesk/', './rawData/turk_sanat/', './rawData/jazz/', './rawData/rap/']

genre_names = ['rock', 'pop', 'arabesk', 'turk_sanat', 'jazz', 'rap']

# %%
def extract_audio_features(audio_path):
    # Load the audio file
    x, sr = librosa.load(audio_path)

    # Initialize dictionary to store features
    features = {}

    # Compute the Short-Time Fourier Transform (STFT)
    stft = librosa.stft(x)
    stft_db = librosa.amplitude_to_db(abs(stft))
    features['stft_db'] = stft_db

    # Compute Spectral Rolloff
    spectral_rolloff = librosa.feature.spectral_rolloff(y=x+0.01, sr=sr)[0]
    # Desired length of the spectral rolloff array
    desired_length = 1280

    # Interpolate the spectral rolloff to the desired length
    if len(spectral_rolloff) != desired_length:
        # Create an interpolation function
        interp_func = interp1d(np.linspace(0, 1, len(spectral_rolloff)), spectral_rolloff, kind='linear')

        # Apply the interpolation to get the desired length
        spectral_rolloff = interp_func(np.linspace(0, 1, desired_length))
        
    features['spectral_rolloff'] = spectral_rolloff

    # Compute Zero Crossing Rate (ZCR)
    zcr = librosa.feature.zero_crossing_rate(x)
    features['zcr'] = zcr

    # Compute Chroma feature
    chroma = librosa.feature.chroma_stft(y=x, sr=sr)
    features['chroma'] = chroma

    # Compute MFCCs
    mfccs = librosa.feature.mfcc(y=x, sr=sr)
    features['mfccs'] = mfccs

    # Compute RMS feature
    rms = librosa.feature.rms(y=x)
    features['rms'] = rms

    # Compute Spectral Centroid feature
    spectral_centroid = librosa.feature.spectral_centroid(y=x, sr=sr)
    features['spectral_centroid'] = spectral_centroid

    return features

# %%
def extract_features_from_genres(genre_names):
    all_features = []
    
    # Iterate through each genre in genre_names
    for genre_index, genre in enumerate(genre_names):
        genre_dir = os.path.join("./rawData", genre)
        
        # Check if genre directory exists
        if os.path.exists(genre_dir):
            print(f"Processing genre: {genre}")
            
            # Iterate through all files in the genre directory
            for root, dirs, files in os.walk(genre_dir):
                for file in files:
                    if file.lower().endswith(('.mp3', '.wav', '.flac')):  # Accept audio files
                        audio_path = os.path.join(root, file)
                        print(f"Extracting features from: {audio_path}")
                        
                        # Extract features from the audio file
                        features = extract_audio_features(audio_path)

                        # Add the file name to the features dictionary
                        features['file_name'] = file
                        features['label'] = genre_index  # Add genre label

                        # Append features to the list
                        all_features.append(features)

    return all_features

# %%
# Extract features from all audio files in the genres
all_features = extract_features_from_genres(genre_names)
# Out:
# Processing genre: rock
# Extracting features from: ./rawData\rock\100_Paramparça.mp3
# Extracting features from: ./rawData\rock\10_Cevapsız Sorular.mp3
# Extracting features from: ./rawData\rock\11_Yıldızlar Üstüne Parlıyorken.mp3
# Extracting features from: ./rawData\rock\12_Haydi Gel İçelim.mp3
# Extracting features from: ./rawData\rock\13_Ben Seni Ararken.mp3
# Extracting features from: ./rawData\rock\14_Anlayamazsın.mp3
# Extracting features from: ./rawData\rock\15_Beni Yakın.mp3
# Extracting features from: ./rawData\rock\16_Aşk Nerden Nereye.mp3
# Extracting features from: ./rawData\rock\17_Sarılsak Geçerdi.mp3
# Extracting features from: ./rawData\rock\18_Oyunbozan.mp3
# Extracting features from: ./rawData\rock\19_Beni Aşka İnandır.mp3
# Extracting features from: ./rawData\rock\1_Belki.mp3
# Extracting features from: ./rawData\rock\20_Her Yol Uçurum.mp3
# Extracting features from: ./rawData\rock\21_Gemiler.mp3
# Extracting features from: ./rawData\rock\22_Gamzedeyim Deva Bulmam.mp3
# Extracting features from: ./rawData\rock\23_Savaşım Kendimle.mp3
# Extracting features from: ./rawData\rock\24_Pembe Mezarlık.mp3
# Extracting features from: ./rawData\rock\25_Nasıl Öğrendin Unutmayı.mp3
# Extracting features from: ./rawData\rock\26_Kendini Bilmezim.mp3
# Extracting features from: ./rawData\rock\27_Anlat Ona.mp3
# Extracting features from: ./rawData\rock\28_Ölürüm Hasretinle.mp3
# Extracting features from: ./rawData\rock\29_Bu Şehir Bizim.mp3
# Extracting features from: ./rawData\rock\2_Bu Akşam.mp3
# Extracting features from: ./rawData\rock\30_Mor Yazma.mp3
# Extracting features from: ./rawData\rock\31_Hiç İyi Değilim.mp3
# Extracting features from: ./rawData\rock\32_Yok.mp3
# Extracting features from: ./rawData\rock\33_O Ben Olamam.mp3
# Extracting features from: ./rawData\rock\34_Hayir Olamaz.mp3
# Extracting features from: ./rawData\rock\35_Gerçeklerin Kıyısında.mp3
# Extracting features from: ./rawData\rock\36_Gökyüzünü Tutamam.mp3
# Extracting features from: ./rawData\rock\37_Yalnızlık Saltanatım.mp3
# Extracting features from: ./rawData\rock\38_Oyuncak Bebek.mp3
# Extracting features from: ./rawData\rock\39_Freud'un Purosu.mp3
# Extracting features from: ./rawData\rock\3_Yıldızların Altında.mp3
# Extracting features from: ./rawData\rock\40_Cinnet.mp3
# Extracting features from: ./rawData\rock\41_Böyle Kahpedir Dünya.mp3
# Extracting features from: ./rawData\rock\42_Sen Ve Ben.mp3
# Extracting features from: ./rawData\rock\43_Sabret.mp3
# Extracting features from: ./rawData\rock\44_Umrumda Değilsin.mp3
# Extracting features from: ./rawData\rock\45_Haram Geceler.mp3
# Extracting features from: ./rawData\rock\46_Sensiz Ben.mp3
# Extracting features from: ./rawData\rock\47_Bir Sevmek Bin Defa Ölmek Demekmiş.mp3
# Extracting features from: ./rawData\rock\48_Yağmurlar.mp3
# Extracting features from: ./rawData\rock\49_Saydim.mp3
# Extracting features from: ./rawData\rock\4_Dibine Kadar.mp3
# Extracting features from: ./rawData\rock\50_Dünyanın En Güzel Kızı.mp3
# Extracting features from: ./rawData\rock\51_Bu Aşk Fazla Sana.mp3
# Extracting features from: ./rawData\rock\52_Sil Baştan.mp3
# Extracting features from: ./rawData\rock\53_Seviyorsan İnanıyorsan.mp3
# Extracting features from: ./rawData\rock\54_Belki Üstümüzden Bir Kuş Geçer.mp3
# Extracting features from: ./rawData\rock\55_Aşk Dediğin.mp3
# Extracting features from: ./rawData\rock\56_Bir Pazar Kahvaltısı.mp3
# Extracting features from: ./rawData\rock\57_Sorun Var.mp3
# Extracting features from: ./rawData\rock\58_Cambaz.mp3
# Extracting features from: ./rawData\rock\59_Meyhaneler Sen....mp3
# Extracting features from: ./rawData\rock\5_Bir Derdim Var.mp3
# Extracting features from: ./rawData\rock\60_Seni Kendime Sakladım.mp3
# Extracting features from: ./rawData\rock\61_Dursun Zaman (feat. Göksel).mp3
# Extracting features from: ./rawData\rock\62_Dokunma.mp3
# Extracting features from: ./rawData\rock\63_Yağmurlar.mp3
# Extracting features from: ./rawData\rock\64_Hint Kumaşı.mp3
# Extracting features from: ./rawData\rock\65_Mey.mp3
# Extracting features from: ./rawData\rock\66_Elfida.mp3
# Extracting features from: ./rawData\rock\67_Her Şeyi Yak.mp3
# Extracting features from: ./rawData\rock\68_Ben Öldüm.mp3
# Extracting features from: ./rawData\rock\69_Kime Ne.mp3
# Extracting features from: ./rawData\rock\6_Anason.mp3
# Extracting features from: ./rawData\rock\70_Elleri Ellerime.mp3
# Extracting features from: ./rawData\rock\71_Olsun.mp3
# Extracting features from: ./rawData\rock\72_Sen Ona Aşıksın - Kabullenme.mp3
# Extracting features from: ./rawData\rock\73_Anladım.mp3
# Extracting features from: ./rawData\rock\74_Sokak Lambası.mp3
# Extracting features from: ./rawData\rock\75_Sen Ağlama.mp3
# Extracting features from: ./rawData\rock\76_Köprüaltı.mp3
# Extracting features from: ./rawData\rock\77_Durma Yağmur Durma.mp3
# Extracting features from: ./rawData\rock\78_Beni Benimle Bırak.mp3
# Extracting features from: ./rawData\rock\79_Bir Melek Vardı.mp3
# Extracting features from: ./rawData\rock\7_Islak Islak.mp3
# Extracting features from: ./rawData\rock\80_Kafile.mp3
# Extracting features from: ./rawData\rock\81_Vazgeçtim Ben Bugün.mp3
# Extracting features from: ./rawData\rock\82_Yalnızlığın Çaresini Bulmuşlar.mp3
# Extracting features from: ./rawData\rock\83_Böyle Ayrılık Olmaz.mp3
# Extracting features from: ./rawData\rock\84_Ağlamam Zaman Aldı - İnkar.mp3
# Extracting features from: ./rawData\rock\85_Kupa Kızı Ve Sinek Valesi.mp3
# Extracting features from: ./rawData\rock\86_Hayalet Sevgilim.mp3
# Extracting features from: ./rawData\rock\87_Ben Seni Arayamam.mp3
# Extracting features from: ./rawData\rock\88_Yürek.mp3
# Extracting features from: ./rawData\rock\89_Serseri.mp3
# Extracting features from: ./rawData\rock\8_Yanında Uyansam.mp3
# Extracting features from: ./rawData\rock\90_Her Aşk Ölümü Tadacak.mp3
# Extracting features from: ./rawData\rock\91_Işıkları Söndürseler Bile.mp3
# Extracting features from: ./rawData\rock\92_Değmesin Ellerimiz.mp3
# Extracting features from: ./rawData\rock\93_Yine Yeni Yeniden - Yeniden Sev.mp3
# Extracting features from: ./rawData\rock\94_Alışırım Gözlerimi Kapamaya.mp3
# Extracting features from: ./rawData\rock\95_Güzel Bir Gün Ölmek İçin.mp3
# Extracting features from: ./rawData\rock\96_Beş.mp3
# Extracting features from: ./rawData\rock\97_Yaz Yaz Yaz.mp3
# Extracting features from: ./rawData\rock\98_Öyle Dertli.mp3
# Extracting features from: ./rawData\rock\99_Bitti Rüya.mp3
# Extracting features from: ./rawData\rock\9_Kendime Yalan Söyledim.mp3
# Processing genre: pop
# Extracting features from: ./rawData\pop\100_Vaziyetler.mp3
# Extracting features from: ./rawData\pop\10_Şans Meleğim.mp3
# Extracting features from: ./rawData\pop\11_Ne Kavgam Bitti Ne Sevdam.mp3
# Extracting features from: ./rawData\pop\12_Senden Çok Var.mp3
# Extracting features from: ./rawData\pop\13_Meyhaneci.mp3
# Extracting features from: ./rawData\pop\14_Ben Güzelden Anlarım.mp3
# Extracting features from: ./rawData\pop\15_Evlenmeliyiz.mp3
# Extracting features from: ./rawData\pop\16_Asuman Pansuman.mp3
# Extracting features from: ./rawData\pop\17_Rütbeni Bileceksin.mp3
# Extracting features from: ./rawData\pop\18_Kalpsizsin.mp3
# Extracting features from: ./rawData\pop\19_Salla.mp3
# Extracting features from: ./rawData\pop\1_Aşkın Ateşi.mp3
# Extracting features from: ./rawData\pop\20_Aman Aman.mp3
# Extracting features from: ./rawData\pop\21_Aşk Gitti Bizden.mp3
# Extracting features from: ./rawData\pop\22_Miş Miş.mp3
# Extracting features from: ./rawData\pop\23_İki Deli.mp3
# Extracting features from: ./rawData\pop\24_Mesafe.mp3
# Extracting features from: ./rawData\pop\25_Gıybet.mp3
# Extracting features from: ./rawData\pop\26_Tuttu Fırlattı.mp3
# Extracting features from: ./rawData\pop\27_Dudak.mp3
# Extracting features from: ./rawData\pop\28_Okyanus.mp3
# Extracting features from: ./rawData\pop\29_Sarışınım.mp3
# Extracting features from: ./rawData\pop\2_Melek.mp3
# Extracting features from: ./rawData\pop\30_Poşet.mp3
# Extracting features from: ./rawData\pop\31_Aşk Kaç Beden Giyer.mp3
# Extracting features from: ./rawData\pop\32_Havaalanı.mp3
# Extracting features from: ./rawData\pop\33_Bodrum.mp3
# Extracting features from: ./rawData\pop\34_Prenses.mp3
# Extracting features from: ./rawData\pop\35_Nerdesin Aşkım.mp3
# Extracting features from: ./rawData\pop\36_Tabi Tabi.mp3
# Extracting features from: ./rawData\pop\37_Dan Dan.mp3
# Extracting features from: ./rawData\pop\38_Çok Çok.mp3
# Extracting features from: ./rawData\pop\39_Şımarık.mp3
# Extracting features from: ./rawData\pop\3_Of Of - First Version.mp3
# Extracting features from: ./rawData\pop\40_Bandıra Bandıra.mp3
# Extracting features from: ./rawData\pop\41_Olmaz Oğlan.mp3
# Extracting features from: ./rawData\pop\42_Irgalamaz Beni.mp3
# Extracting features from: ./rawData\pop\43_Mor.mp3
# Extracting features from: ./rawData\pop\44_Cevapsız Çınlama.mp3
# Extracting features from: ./rawData\pop\45_Yakar Geçerim.mp3
# Extracting features from: ./rawData\pop\46_Sallayalım Dünyayı.mp3
# Extracting features from: ./rawData\pop\47_Kendime Yeni Bir Ben Lazım.mp3
# Extracting features from: ./rawData\pop\48_Alt Dudak.mp3
# Extracting features from: ./rawData\pop\49_Seni Yerler.mp3
# Extracting features from: ./rawData\pop\4_Bebek.mp3
# Extracting features from: ./rawData\pop\50_Rengarenk.mp3
# Extracting features from: ./rawData\pop\51_Ya Ya Ya Ya.mp3
# Extracting features from: ./rawData\pop\52_Evli, Mutlu, Çocuklu.mp3
# Extracting features from: ./rawData\pop\53_Yanayım Yanayım.mp3
# Extracting features from: ./rawData\pop\54_Bekar Gezelim.mp3
# Extracting features from: ./rawData\pop\55_Yalan.mp3
# Extracting features from: ./rawData\pop\56_Karabiberim.mp3
# Extracting features from: ./rawData\pop\57_Yatcaz Kalkcaz Ordayım.mp3
# Extracting features from: ./rawData\pop\58_Yaparım Bilirsin.mp3
# Extracting features from: ./rawData\pop\59_Adeyyo.mp3
# Extracting features from: ./rawData\pop\5_Toz Pembe.mp3
# Extracting features from: ./rawData\pop\60_Manifesto.mp3
# Extracting features from: ./rawData\pop\61_Çalkala.mp3
# Extracting features from: ./rawData\pop\62_Her gece.mp3
# Extracting features from: ./rawData\pop\63_Bas Gaza.mp3
# Extracting features from: ./rawData\pop\64_Yolla.mp3
# Extracting features from: ./rawData\pop\65_Bangır Bangır.mp3
# Extracting features from: ./rawData\pop\66_Keyfi Yolunda Aşkı Sonunda.mp3
# Extracting features from: ./rawData\pop\67_Dağılmak İstiyorum.mp3
# Extracting features from: ./rawData\pop\68_Türkan.mp3
# Extracting features from: ./rawData\pop\69_İltimas.mp3
# Extracting features from: ./rawData\pop\6_Çakkıdı.mp3
# Extracting features from: ./rawData\pop\72_Dantel.mp3
# Extracting features from: ./rawData\pop\73_Kulüp.mp3
# Extracting features from: ./rawData\pop\74_Olan Var Olmayan Var.mp3
# Extracting features from: ./rawData\pop\75_...dan sonra.mp3
# Extracting features from: ./rawData\pop\76_Harika.mp3
# Extracting features from: ./rawData\pop\77_Bir Tanecik Aşkım.mp3
# Extracting features from: ./rawData\pop\78_Bir Güzellik Yap.mp3
# Extracting features from: ./rawData\pop\79_Istanbul.mp3
# Extracting features from: ./rawData\pop\7_Dansöz.mp3
# Extracting features from: ./rawData\pop\80_Ölürüm Sana.mp3
# Extracting features from: ./rawData\pop\81_Çak Bir Selam - Gurcell Style Mix.mp3
# Extracting features from: ./rawData\pop\82_Aldatıldık.mp3
# Extracting features from: ./rawData\pop\83_Geççek.mp3
# Extracting features from: ./rawData\pop\84_Martılar.mp3
# Extracting features from: ./rawData\pop\85_Yalan.mp3
# Extracting features from: ./rawData\pop\86_Romeo.mp3
# Extracting features from: ./rawData\pop\87_Uçacaksın.mp3
# Extracting features from: ./rawData\pop\88_Kırmızı.mp3
# Extracting features from: ./rawData\pop\89_Alain Delon.mp3
# Extracting features from: ./rawData\pop\8_Komple.mp3
# Extracting features from: ./rawData\pop\90_Şak Şuka.mp3
# Extracting features from: ./rawData\pop\91_Hüp.mp3
# Extracting features from: ./rawData\pop\92_Bombabomba.com.mp3
# Extracting features from: ./rawData\pop\93_Pırlanta.mp3
# Extracting features from: ./rawData\pop\94_Öp.mp3
# Extracting features from: ./rawData\pop\95_Seviyorum Sevmiyorum.mp3
# Extracting features from: ./rawData\pop\96_Adımı Kalbine Yaz.mp3
# Extracting features from: ./rawData\pop\97_Doktor.mp3
# Extracting features from: ./rawData\pop\98_Gir Kanıma.mp3
# Extracting features from: ./rawData\pop\99_Kuzu Kuzu.mp3
# Extracting features from: ./rawData\pop\9_Pazara Kadar.mp3
# Processing genre: arabesk
# Extracting features from: ./rawData\arabesk\100_Unutmak Yalan.mp3
# Extracting features from: ./rawData\arabesk\10_Resmini Öptümde Yattım.mp3
# Extracting features from: ./rawData\arabesk\11_Sevsen Ne Olurdu.mp3
# Extracting features from: ./rawData\arabesk\12_Beni Kaybettin Artık.mp3
# Extracting features from: ./rawData\arabesk\13_Ben de Özledim.mp3
# Extracting features from: ./rawData\arabesk\14_Huzurum Kalmadı.mp3
# Extracting features from: ./rawData\arabesk\15_Değmezmiş Sana.mp3
# Extracting features from: ./rawData\arabesk\16_Hatasız Kul Olmaz.mp3
# Extracting features from: ./rawData\arabesk\17_Bir Ateşe Attın Beni.mp3
# Extracting features from: ./rawData\arabesk\18_Küllenen Aşk.mp3
# Extracting features from: ./rawData\arabesk\19_Sen Affetsen.mp3
# Extracting features from: ./rawData\arabesk\1_Sabahçı Kahvesi.mp3
# Extracting features from: ./rawData\arabesk\20_Seninle Olmak Varya.mp3
# Extracting features from: ./rawData\arabesk\21_Bir Gülü Sevdim.mp3
# Extracting features from: ./rawData\arabesk\22_Yaktı Beni.mp3
# Extracting features from: ./rawData\arabesk\23_Yaralıyım Dertliyim.mp3
# Extracting features from: ./rawData\arabesk\24_Kurtuldum.mp3
# Extracting features from: ./rawData\arabesk\25_Farketmez Artık.mp3
# Extracting features from: ./rawData\arabesk\26_Adını Yollara Yazdım.mp3
# Extracting features from: ./rawData\arabesk\27_Geçen Yıl.mp3
# Extracting features from: ./rawData\arabesk\28_Emmioğlu.mp3
# Extracting features from: ./rawData\arabesk\29_Koparma Gülleri.mp3
# Extracting features from: ./rawData\arabesk\2_Sanmaki Yaşıyorum.mp3
# Extracting features from: ./rawData\arabesk\30_Bana Ondan Bahsetmeyin.mp3
# Extracting features from: ./rawData\arabesk\31_Yüreğimde Yara Var.mp3
# Extracting features from: ./rawData\arabesk\32_Bilemezsin Sen.mp3
# Extracting features from: ./rawData\arabesk\33_Son Mektup.mp3
# Extracting features from: ./rawData\arabesk\34_Kul Hatasız Olmaz.mp3
# Extracting features from: ./rawData\arabesk\35_Ağla Gözüm.mp3
# Extracting features from: ./rawData\arabesk\36_Sevme.mp3
# Extracting features from: ./rawData\arabesk\37_Yorgun Yıllarım.mp3
# Extracting features from: ./rawData\arabesk\38_Sevemedim Kara Gözlüm.mp3
# Extracting features from: ./rawData\arabesk\39_Duyanlara Duymayanlara.mp3
# Extracting features from: ./rawData\arabesk\3_Bana Da Söyle.mp3
# Extracting features from: ./rawData\arabesk\40_Gece Olunca.mp3
# Extracting features from: ./rawData\arabesk\41_Duvardaki.mp3
# Extracting features from: ./rawData\arabesk\42_Liselim.mp3
# Extracting features from: ./rawData\arabesk\43_Unutulan.mp3
# Extracting features from: ./rawData\arabesk\44_Gündüzüm Seninle.mp3
# Extracting features from: ./rawData\arabesk\45_Geceler Kara Tren.mp3
# Extracting features from: ./rawData\arabesk\46_Hasret Akşamları.mp3
# Extracting features from: ./rawData\arabesk\47_İtirazım Var.mp3
# Extracting features from: ./rawData\arabesk\48_Seni Kalbimden Kovdum.mp3
# Extracting features from: ./rawData\arabesk\49_İnsan Dertli Olunca.mp3
# Extracting features from: ./rawData\arabesk\4_Sevda Yelleri.mp3
# Extracting features from: ./rawData\arabesk\50_Sevgiler Çiçek Gibi.mp3
# Extracting features from: ./rawData\arabesk\51_Kopamam Senden.mp3
# Extracting features from: ./rawData\arabesk\52_Benim Olsaydın.mp3
# Extracting features from: ./rawData\arabesk\53_Unutmaya Ömrüm Yeter Mi.mp3
# Extracting features from: ./rawData\arabesk\54_Hain Geceler.mp3
# Extracting features from: ./rawData\arabesk\55_Heves Mi Sandın.mp3
# Extracting features from: ./rawData\arabesk\56_Sensizim.mp3
# Extracting features from: ./rawData\arabesk\57_Unutulmuşum.mp3
# Extracting features from: ./rawData\arabesk\58_Ben De Unuturum.mp3
# Extracting features from: ./rawData\arabesk\59_Ödüm Kopuyor.mp3
# Extracting features from: ./rawData\arabesk\5_Hatıran Yeter.mp3
# Extracting features from: ./rawData\arabesk\60_Sahte Sevgililer.mp3
# Extracting features from: ./rawData\arabesk\61_Kaderimin Oyunu.mp3
# Extracting features from: ./rawData\arabesk\62_Sen Aldırma.mp3
# Extracting features from: ./rawData\arabesk\63_Kal Benim İçin.mp3
# Extracting features from: ./rawData\arabesk\64_Dargınım.mp3
# Extracting features from: ./rawData\arabesk\65_Hatırası Var.mp3
# Extracting features from: ./rawData\arabesk\66_Duydum Ki Unutmuşsun.mp3
# Extracting features from: ./rawData\arabesk\67_Küskünüm.mp3
# Extracting features from: ./rawData\arabesk\68_İçim Yanar.mp3
# Extracting features from: ./rawData\arabesk\69_Sırılsıklam.mp3
# Extracting features from: ./rawData\arabesk\6_Bana Sor.mp3
# Extracting features from: ./rawData\arabesk\70_Ben Tövbemi Geri Aldım.mp3
# Extracting features from: ./rawData\arabesk\71_Eller Aldı.mp3
# Extracting features from: ./rawData\arabesk\72_Elveda Sevgilim.mp3
# Extracting features from: ./rawData\arabesk\73_Bu Şehrin Geceleri.mp3
# Extracting features from: ./rawData\arabesk\74_Hasret Sancısı.mp3
# Extracting features from: ./rawData\arabesk\75_Yaktın Beni Dünya.mp3
# Extracting features from: ./rawData\arabesk\76_Yıllarım.mp3
# Extracting features from: ./rawData\arabesk\77_Zaman Geldi.mp3
# Extracting features from: ./rawData\arabesk\78_Geceler.mp3
# Extracting features from: ./rawData\arabesk\79_Rüyalarda Buluşuruz.mp3
# Extracting features from: ./rawData\arabesk\80_Yalnızım.mp3
# Extracting features from: ./rawData\arabesk\81_Duyanlara Duymayanlara.mp3
# Extracting features from: ./rawData\arabesk\82_Yalan Gözler.mp3
# Extracting features from: ./rawData\arabesk\83_Neden Dönmesin.mp3
# Extracting features from: ./rawData\arabesk\84_Yine Mi Sen.mp3
# Extracting features from: ./rawData\arabesk\85_Okul Yılları.mp3
# Extracting features from: ./rawData\arabesk\86_Sensiz İki Gün.mp3
# Extracting features from: ./rawData\arabesk\87_Unuttum İşte.mp3
# Extracting features from: ./rawData\arabesk\88_Bu Şehir.mp3
# Extracting features from: ./rawData\arabesk\89_Bitmiyor Geceler.mp3
# Extracting features from: ./rawData\arabesk\8_Ben Olmalıydım.mp3
# Extracting features from: ./rawData\arabesk\90_Sensizliğe Alışamadım.mp3
# Extracting features from: ./rawData\arabesk\91_Üstüme Düşme Benim.mp3
# Extracting features from: ./rawData\arabesk\92_Üzülmedim Ki.mp3
# Extracting features from: ./rawData\arabesk\93_Gizli Sevda.mp3
# Extracting features from: ./rawData\arabesk\94_Bu Günler Yaşanacak.mp3
# Extracting features from: ./rawData\arabesk\95_Feleğin İşine Bak.mp3
# Extracting features from: ./rawData\arabesk\96_Sana Hasret Gideceğim.mp3
# Extracting features from: ./rawData\arabesk\97_Kısmet Olmadı.mp3
# Extracting features from: ./rawData\arabesk\98_Sensiz Yaşamaya Alışacağım.mp3
# Extracting features from: ./rawData\arabesk\99_Farkında Mısın.mp3
# Extracting features from: ./rawData\arabesk\9_Sev Yeter.mp3
# Processing genre: turk_sanat
# Extracting features from: ./rawData\turk_sanat\100_Leyla Bir Özgecandır.mp3
# Extracting features from: ./rawData\turk_sanat\10_Bir Gece Ansızın Gelebilirim.mp3
# Extracting features from: ./rawData\turk_sanat\11_Gitme Sana Muhtacım.mp3
# Extracting features from: ./rawData\turk_sanat\12_Şimdi Uzaklardasın.mp3
# Extracting features from: ./rawData\turk_sanat\13_Gözlerin Doğuyor Gecelerime.mp3
# Extracting features from: ./rawData\turk_sanat\14_Sevmekten Kim Usanır.mp3
# Extracting features from: ./rawData\turk_sanat\15_Olmaz Ilaç Sine I Sad Pareme.mp3
# Extracting features from: ./rawData\turk_sanat\16_Seni Sordum Yıldızlara.mp3
# Extracting features from: ./rawData\turk_sanat\17_Aşkın Kanunu.mp3
# Extracting features from: ./rawData\turk_sanat\18_Bir Bahar Akşamı.mp3
# Extracting features from: ./rawData\turk_sanat\19_Ben Seni Unutmak İçin Sevmedim.mp3
# Extracting features from: ./rawData\turk_sanat\1_Ah Bu Şarkıların Gözü Kör Olsun.mp3
# Extracting features from: ./rawData\turk_sanat\20_Talihin Elinde Oyuncak Oldum.mp3
# Extracting features from: ./rawData\turk_sanat\21_Sevemez Kimse Seni.mp3
# Extracting features from: ./rawData\turk_sanat\22_Dargın Ayrılmayalım.mp3
# Extracting features from: ./rawData\turk_sanat\23_Yıldızların Altında.mp3
# Extracting features from: ./rawData\turk_sanat\24_Unutturamaz Seni Hiçbir Şey.mp3
# Extracting features from: ./rawData\turk_sanat\25_Söyleyemem Derdimi.mp3
# Extracting features from: ./rawData\turk_sanat\26_Ben Küskünüm Feleğe.mp3
# Extracting features from: ./rawData\turk_sanat\27_Bak Yeşil Yeşil.mp3
# Extracting features from: ./rawData\turk_sanat\28_Nasıl Geçti Habersiz O Güzelim Yıllarım.mp3
# Extracting features from: ./rawData\turk_sanat\29_Silemezler Gönlümden.mp3
# Extracting features from: ./rawData\turk_sanat\2_Bir İhtimal Daha Var.mp3
# Extracting features from: ./rawData\turk_sanat\30_Elveda Meyhaneci.mp3
# Extracting features from: ./rawData\turk_sanat\31_Sen Sevgini Bana Sakla.mp3
# Extracting features from: ./rawData\turk_sanat\32_Yine Bir Gul-Nihal Aldi Bu Gonlumu.mp3
# Extracting features from: ./rawData\turk_sanat\33_Baharı Bekleyen Kumrular Gibi.mp3
# Extracting features from: ./rawData\turk_sanat\34_Kadere Bak.mp3
# Extracting features from: ./rawData\turk_sanat\35_Rüyalarda Buluşuruz.mp3
# Extracting features from: ./rawData\turk_sanat\36_Dediler Zamanla Hep Azalmış Sevgiler Olsun.mp3
# Extracting features from: ./rawData\turk_sanat\37_Enginde Yavaş Yavaş.mp3
# Extracting features from: ./rawData\turk_sanat\38_İnleyen Nağmeler Ruhumu Sardı.mp3
# Extracting features from: ./rawData\turk_sanat\39_Dertliyim Ruhuma Hicranımı.mp3
# Extracting features from: ./rawData\turk_sanat\3_Söyleme Bilmesinler Bu Aşkın Bittiğini.mp3
# Extracting features from: ./rawData\turk_sanat\40_Fikrimin İnce Gülü.mp3
# Extracting features from: ./rawData\turk_sanat\41_Sorma Ne Haldeyim.mp3
# Extracting features from: ./rawData\turk_sanat\42_Dilek Taşı.mp3
# Extracting features from: ./rawData\turk_sanat\43_Eski Dostlar.mp3
# Extracting features from: ./rawData\turk_sanat\44_Sevgi Dolu Şu Gönlüm.mp3
# Extracting features from: ./rawData\turk_sanat\45_Kirpiklerinin Gölgesi Güllerle Bezenmiş.mp3
# Extracting features from: ./rawData\turk_sanat\46_Madem Ki Gidiyorsun.mp3
# Extracting features from: ./rawData\turk_sanat\47_Nereye Gidiyorum.mp3
# Extracting features from: ./rawData\turk_sanat\48_Kadehinde Zehir Olsa.mp3
# Extracting features from: ./rawData\turk_sanat\4_Elbet Birgün Buluşacağız.mp3
# Extracting features from: ./rawData\turk_sanat\50_Pişman Olur Da Bir Gün.mp3
# Extracting features from: ./rawData\turk_sanat\51_Kırmızı Gülün Alı Var.mp3
# Extracting features from: ./rawData\turk_sanat\52_Agora Meyhanesi.mp3
# Extracting features from: ./rawData\turk_sanat\53_Dil Harab-ı Aşkınım Sensin Sebep Berbadıma.mp3
# Extracting features from: ./rawData\turk_sanat\54_Dök Zülfünü Meydana Gel.mp3
# Extracting features from: ./rawData\turk_sanat\55_İmkansız.mp3
# Extracting features from: ./rawData\turk_sanat\56_Tuti-i Mucize Guyem.mp3
# Extracting features from: ./rawData\turk_sanat\57_Bir Kızıl Goncaya Benzer Dudağın.mp3
# Extracting features from: ./rawData\turk_sanat\58_Mehtaplı Gecelerde.mp3
# Extracting features from: ./rawData\turk_sanat\59_Seviyorum İşte Var mı Diyeceğin.mp3
# Extracting features from: ./rawData\turk_sanat\5_Niçin Baktın Bana Öyle.mp3
# Extracting features from: ./rawData\turk_sanat\60_Sevemedim Karagözlüm.mp3
# Extracting features from: ./rawData\turk_sanat\61_Şarkılara Sordum.mp3
# Extracting features from: ./rawData\turk_sanat\62_Kız Sen İstanbul'un Neresindensin.mp3
# Extracting features from: ./rawData\turk_sanat\63_Yanıyor Mu Yeşil Köşkün Lambası.mp3
# Extracting features from: ./rawData\turk_sanat\64_Bekledim De Gelmedin.mp3
# Extracting features from: ./rawData\turk_sanat\65_Rüzgar Susmuş Ses Vermiyor.mp3
# Extracting features from: ./rawData\turk_sanat\66_Kadifeden Kesesi.mp3
# Extracting features from: ./rawData\turk_sanat\67_Bakmıyor Çeşm-i Siyah Feryade - Gazelli.mp3
# Extracting features from: ./rawData\turk_sanat\68_Ömrümüzün Son Demi.mp3
# Extracting features from: ./rawData\turk_sanat\69_Ayrılık Yaman Kelime.mp3
# Extracting features from: ./rawData\turk_sanat\6_Duydum ki Unutmuşsun.mp3
# Extracting features from: ./rawData\turk_sanat\70_Gözyaşımda Saklısın.mp3
# Extracting features from: ./rawData\turk_sanat\71_Kapın Her Çalındıkça.mp3
# Extracting features from: ./rawData\turk_sanat\72_Bir Gönlüme Bir Hali Perişanıma Baktım.mp3
# Extracting features from: ./rawData\turk_sanat\73_Kulakların Çınlasın.mp3
# Extracting features from: ./rawData\turk_sanat\74_Gücüme Gidiyor Böyle Yaşamak.mp3
# Extracting features from: ./rawData\turk_sanat\75_Sen Kimseyi Sevemezsin.mp3
# Extracting features from: ./rawData\turk_sanat\76_Ben Gamlı Hazan Sense Bahar.mp3
# Extracting features from: ./rawData\turk_sanat\77_Alıverin Bağlamamı Çalayım.mp3
# Extracting features from: ./rawData\turk_sanat\78_Ne Senin Aşkına Muhtaç.mp3
# Extracting features from: ./rawData\turk_sanat\79_Gezdiğim Dikenli Aşk Yollarında.mp3
# Extracting features from: ./rawData\turk_sanat\7_Gündüzüm Seninle.mp3
# Extracting features from: ./rawData\turk_sanat\80_Nazende Sevgilim.mp3
# Extracting features from: ./rawData\turk_sanat\81_Her Yer Karanlık (Makber).mp3
# Extracting features from: ./rawData\turk_sanat\82_Akasyalar Açarken.mp3
# Extracting features from: ./rawData\turk_sanat\83_Böyle Mi Esecekti.mp3
# Extracting features from: ./rawData\turk_sanat\84_Kederli Günlerimde.mp3
# Extracting features from: ./rawData\turk_sanat\85_Buruk Acı.mp3
# Extracting features from: ./rawData\turk_sanat\86_Her Gece Yollarda Gözledim Seni.mp3
# Extracting features from: ./rawData\turk_sanat\87_Gönlüm Seher Yeli Gibi.mp3
# Extracting features from: ./rawData\turk_sanat\88_Şarkılar Seni Söyler.mp3
# Extracting features from: ./rawData\turk_sanat\89_Benzemez Kimse Sana.mp3
# Extracting features from: ./rawData\turk_sanat\8_Nihansın Dideden.mp3
# Extracting features from: ./rawData\turk_sanat\90_Veda Busesi.mp3
# Extracting features from: ./rawData\turk_sanat\91_Bir Demet Yasemen.mp3
# Extracting features from: ./rawData\turk_sanat\92_At Kadehi Elinden.mp3
# Extracting features from: ./rawData\turk_sanat\93_Bu Ne Sevgi Ah Bu Ne Izdırap.mp3
# Extracting features from: ./rawData\turk_sanat\94_Rindlerin Akşamı - Dönülmez Akşamın Ufkundayız.mp3
# Extracting features from: ./rawData\turk_sanat\95_Bu Akşam Bütün Meyhanelerini Dolaştım İstanbul'un.mp3
# Extracting features from: ./rawData\turk_sanat\96_Sesimde Şarkısı Aşkın.mp3
# Extracting features from: ./rawData\turk_sanat\97_Kimler Unutmadı Ki.mp3
# Extracting features from: ./rawData\turk_sanat\98_Karam.mp3
# Extracting features from: ./rawData\turk_sanat\99_İndim Havuz Başına.mp3
# Extracting features from: ./rawData\turk_sanat\9_Kimseye Etmem Şikayet.mp3
# Processing genre: jazz
# Extracting features from: ./rawData\jazz\10_Kaybolan Yıllar.mp3
# Extracting features from: ./rawData\jazz\11_Her Şeyi Yak.mp3
# Extracting features from: ./rawData\jazz\12_Farketmeden.mp3
# Extracting features from: ./rawData\jazz\13_Aşk Bu Değil.mp3
# Extracting features from: ./rawData\jazz\15_Şarkı Söylemek Lazım.mp3
# Extracting features from: ./rawData\jazz\16_Sen Ağlama.mp3
# Extracting features from: ./rawData\jazz\17_Şarkıcının Şarkısı.mp3
# Extracting features from: ./rawData\jazz\18_Olur Ya.mp3
# Extracting features from: ./rawData\jazz\19_Aldatıldık.mp3
# Extracting features from: ./rawData\jazz\1_İstanbul.mp3
# Extracting features from: ./rawData\jazz\20_Gesi Baglari.mp3
# Extracting features from: ./rawData\jazz\21_Her Yaşın Ayrı Bir Güzelliği Var.mp3
# Extracting features from: ./rawData\jazz\22_Bilsen.mp3
# Extracting features from: ./rawData\jazz\23_Zaman Olur.mp3
# Extracting features from: ./rawData\jazz\24_Kanatlarım Var Ruhumda.mp3
# Extracting features from: ./rawData\jazz\25_Aşık Olmak İstemem.mp3
# Extracting features from: ./rawData\jazz\27_İhtimal.mp3
# Extracting features from: ./rawData\jazz\28_Büklüm Büklüm.mp3
# Extracting features from: ./rawData\jazz\29_Öyledir Geçer Zaman.mp3
# Extracting features from: ./rawData\jazz\2_Suya Orak.mp3
# Extracting features from: ./rawData\jazz\30_Katibim.mp3
# Extracting features from: ./rawData\jazz\33_Hep Böyle Kal.mp3
# Extracting features from: ./rawData\jazz\34_Paramparça.mp3
# Extracting features from: ./rawData\jazz\35_Her Akşam Votka Rakı ve Şarap (Sarhoş).mp3
# Extracting features from: ./rawData\jazz\36_Beni Benimle Bırak.mp3
# Extracting features from: ./rawData\jazz\37_Pervane.mp3
# Extracting features from: ./rawData\jazz\38_Bu Aşk Fazla Sana.mp3
# Extracting features from: ./rawData\jazz\39_Küçüğüm.mp3
# Extracting features from: ./rawData\jazz\3_Resim - İlker Tandoğan Remix.mp3
# Extracting features from: ./rawData\jazz\41_İstanbul Kafası.mp3
# Extracting features from: ./rawData\jazz\43_Teselli.mp3
# Extracting features from: ./rawData\jazz\47_Tutamıyorum Zamanı - Akustik.mp3
# Extracting features from: ./rawData\jazz\49_Bir Harmanım Bu Akşam.mp3
# Extracting features from: ./rawData\jazz\4_Deli Mavi.mp3
# Extracting features from: ./rawData\jazz\52_Kaç Yıl Geçti Aradan.mp3
# Extracting features from: ./rawData\jazz\54_Ne Tuhaf.mp3
# Extracting features from: ./rawData\jazz\56_Yine Tek.mp3
# Extracting features from: ./rawData\jazz\57_Neler Oluyor Bize (feat. Burcin Buke).mp3
# Extracting features from: ./rawData\jazz\58_Güllerim Soldu.mp3
# Extracting features from: ./rawData\jazz\59_Leyla.mp3
# Extracting features from: ./rawData\jazz\5_Hasret.mp3
# Extracting features from: ./rawData\jazz\61_Sonbahar Rüzgarları.mp3
# Extracting features from: ./rawData\jazz\63_Gözleri Aşka Gülen.mp3
# Extracting features from: ./rawData\jazz\64_Kayboldum - El Ciego.mp3
# Extracting features from: ./rawData\jazz\66_Ya Sonra.mp3
# Extracting features from: ./rawData\jazz\67_Yalgızam.mp3
# Extracting features from: ./rawData\jazz\69_Öyle Sarhoş Olsam Ki.mp3
# Extracting features from: ./rawData\jazz\6_Gesi Bağları - Live at The Royal Concertgebouw.mp3
# Extracting features from: ./rawData\jazz\70_Merkür Retrosu.mp3
# Extracting features from: ./rawData\jazz\75_Baş Harfi Ben.mp3
# Extracting features from: ./rawData\jazz\77_Özlediğim.mp3
# Extracting features from: ./rawData\jazz\79_Bir Fırtına Tuttu Bizi.mp3
# Extracting features from: ./rawData\jazz\81_Sen Varsın.mp3
# Extracting features from: ./rawData\jazz\83_Nar Tanesi.mp3
# Extracting features from: ./rawData\jazz\84_Ben Böyleyim.mp3
# Extracting features from: ./rawData\jazz\85_Sana Bana Yeter.mp3
# Extracting features from: ./rawData\jazz\86_Her Yaşın Ayrı Bir Güzelliği Var.mp3
# Extracting features from: ./rawData\jazz\88_Bana Yalan Söylediler.mp3
# Extracting features from: ./rawData\jazz\89_Bir Günah Gibi.mp3
# Extracting features from: ./rawData\jazz\8_Yalan Dünya.mp3
# Extracting features from: ./rawData\jazz\91_Hiç Sanmam (feat. Burcin Buke).mp3
# Extracting features from: ./rawData\jazz\93_Son Yolcu.mp3
# Extracting features from: ./rawData\jazz\94_Hatıralar.mp3
# Extracting features from: ./rawData\jazz\95_Gurbet.mp3
# Extracting features from: ./rawData\jazz\96_Pasiflora.mp3
# Extracting features from: ./rawData\jazz\9_Delikanlı.mp3
# Processing genre: rap
# Extracting features from: ./rawData\rap\100_Yola Koyul.mp3
# Extracting features from: ./rawData\rap\10_Sağlam Kalça.mp3
# Extracting features from: ./rawData\rap\11_pVg.mp3
# Extracting features from: ./rawData\rap\12_Bertaraf.mp3
# Extracting features from: ./rawData\rap\13_AFFETMEM.mp3
# Extracting features from: ./rawData\rap\14_SADECE.mp3
# Extracting features from: ./rawData\rap\15_ISRAR.mp3
# Extracting features from: ./rawData\rap\16_DAMLA.mp3
# Extracting features from: ./rawData\rap\17_MINI TERORISTA.mp3
# Extracting features from: ./rawData\rap\18_İçindeki Ses.mp3
# Extracting features from: ./rawData\rap\19_International.mp3
# Extracting features from: ./rawData\rap\1_Nerdesin.mp3
# Extracting features from: ./rawData\rap\20_Keşmekeş.mp3
# Extracting features from: ./rawData\rap\21_Elimde Değil.mp3
# Extracting features from: ./rawData\rap\22_Gelsin Hayat Bildiği Gibi.mp3
# Extracting features from: ./rawData\rap\23_Reenkarne.mp3
# Extracting features from: ./rawData\rap\24_Aşk Olsun.mp3
# Extracting features from: ./rawData\rap\25_Böyle İyi.mp3
# Extracting features from: ./rawData\rap\26_Yol.mp3
# Extracting features from: ./rawData\rap\27_Merhametine Dön (2021 Tek Edit).mp3
# Extracting features from: ./rawData\rap\28_ARABA.mp3
# Extracting features from: ./rawData\rap\29_Geceler.mp3
# Extracting features from: ./rawData\rap\2_A La Carte.mp3
# Extracting features from: ./rawData\rap\30_Caney.mp3
# Extracting features from: ./rawData\rap\31_Tanrım Reva Mı.mp3
# Extracting features from: ./rawData\rap\32_Love, Gun.mp3
# Extracting features from: ./rawData\rap\33_Özlesen Beni.mp3
# Extracting features from: ./rawData\rap\34_SENIN UGRUNA.mp3
# Extracting features from: ./rawData\rap\36_Yemin Olsun.mp3
# Extracting features from: ./rawData\rap\37_YAPTIRICAZ TIRNAKLARINI.mp3
# Extracting features from: ./rawData\rap\38_MERVE - Masada Chivas.mp3
# Extracting features from: ./rawData\rap\39_RANDEVU.mp3
# Extracting features from: ./rawData\rap\3_Margiela.mp3
# Extracting features from: ./rawData\rap\40_Ateşten Gömlek.mp3
# Extracting features from: ./rawData\rap\41_N'aptığını bilmesem de.mp3
# Extracting features from: ./rawData\rap\42_Pişman Değilim.mp3
# Extracting features from: ./rawData\rap\43_GAZ PEDAL.mp3
# Extracting features from: ./rawData\rap\45_10MG.mp3
# Extracting features from: ./rawData\rap\46_Yine Edemedik Dans.mp3
# Extracting features from: ./rawData\rap\47_GMER.mp3
# Extracting features from: ./rawData\rap\49_Geriye Dönemem.mp3
# Extracting features from: ./rawData\rap\4_Salla Salla.mp3
# Extracting features from: ./rawData\rap\50_ZOR.mp3
# Extracting features from: ./rawData\rap\51_Özür.mp3
# Extracting features from: ./rawData\rap\52_İZLEDİ MAHALLE.mp3
# Extracting features from: ./rawData\rap\53_Cuma.mp3
# Extracting features from: ./rawData\rap\54_NKBİ X YAPAMAM - Remix.mp3
# Extracting features from: ./rawData\rap\55_BABA.mp3
# Extracting features from: ./rawData\rap\56_25.mp3
# Extracting features from: ./rawData\rap\57_BAYBAY.mp3
# Extracting features from: ./rawData\rap\58_DEFOL.mp3
# Extracting features from: ./rawData\rap\59_Gözler Yalan Söylemez.mp3
# Extracting features from: ./rawData\rap\5_Gecelerim.mp3
# Extracting features from: ./rawData\rap\60_HONG KONG.mp3
# Extracting features from: ./rawData\rap\61_KHRBR.mp3
# Extracting features from: ./rawData\rap\62_Nedenini Sorma.mp3
# Extracting features from: ./rawData\rap\63_Aksiyon.mp3
# Extracting features from: ./rawData\rap\64_Inzaghi.mp3
# Extracting features from: ./rawData\rap\65_BAKSANA BİLADER - Saz Mi Caz Mi.mp3
# Extracting features from: ./rawData\rap\66_GANG.mp3
# Extracting features from: ./rawData\rap\67_UNUTTUM.mp3
# Extracting features from: ./rawData\rap\68_Sevmiş Gibi.mp3
# Extracting features from: ./rawData\rap\69_YAPAMAM.mp3
# Extracting features from: ./rawData\rap\6_İlle de Sen.mp3
# Extracting features from: ./rawData\rap\70_DACIA.mp3
# Extracting features from: ./rawData\rap\71_Birader.mp3
# Extracting features from: ./rawData\rap\72_olsun.mp3
# Extracting features from: ./rawData\rap\73_NEGATIF.mp3
# Extracting features from: ./rawData\rap\74_Feragât.mp3
# Extracting features from: ./rawData\rap\75_KÂR.mp3
# Extracting features from: ./rawData\rap\76_PARA.mp3
# Extracting features from: ./rawData\rap\77_ARASAN DA.mp3
# Extracting features from: ./rawData\rap\78_Trankobuskas - Remix.mp3
# Extracting features from: ./rawData\rap\79_LE CANE.mp3
# Extracting features from: ./rawData\rap\7_DOĞUŞTAN BERİ HAKLIYIM (tmm).mp3
# Extracting features from: ./rawData\rap\80_10 NUMARA.mp3
# Extracting features from: ./rawData\rap\81_Nerdesin.mp3
# Extracting features from: ./rawData\rap\82_Affettim.mp3
# Extracting features from: ./rawData\rap\83_Umrumda Değil.mp3
# Extracting features from: ./rawData\rap\84_GECELERİN DERDİ.mp3
# Extracting features from: ./rawData\rap\85_ıslak kum.mp3
# Extracting features from: ./rawData\rap\86_Makina.mp3
# Extracting features from: ./rawData\rap\87_FESTİVAL.mp3
# Extracting features from: ./rawData\rap\88_Film.mp3
# Extracting features from: ./rawData\rap\89_Ağlattın.mp3
# Extracting features from: ./rawData\rap\8_Aman Güzel Yavaş Yürü.mp3
# Extracting features from: ./rawData\rap\90_CINDY.mp3
# Extracting features from: ./rawData\rap\91_2T1BB.mp3
# Extracting features from: ./rawData\rap\92_Daima.mp3
# Extracting features from: ./rawData\rap\93_KALA KAL.mp3
# Extracting features from: ./rawData\rap\94_OnlyFans.mp3
# Extracting features from: ./rawData\rap\95_KONTROL.mp3
# Extracting features from: ./rawData\rap\96_Değilim Bi Aşık.mp3
# Extracting features from: ./rawData\rap\97_Outro.mp3
# Extracting features from: ./rawData\rap\98_Nereden.mp3
# Extracting features from: ./rawData\rap\9_JET BABA.mp3

# %%
with open('features.pkl', 'wb') as f:
    pickle.dump(all_features, f)

print(f"Extracted features for {len(all_features)} audio files.")
# Out:
# Extracted features for 558 audio files.

# %% [markdown]
# # The 1D features are all of same length 1280 but 2D features are of different length in both dimensions also they can't be collapsed into 1D since it would be nonsensical because of their information type. So this is the final

# %%
# Open the pickle file in read-binary mode
with open('features.pkl', 'rb') as file:
    # Load the content of the pickle file into a Python object
    loaded_object = pickle.load(file)

# Now you can use the loaded object as needed
print(loaded_object[0])
# Out:
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x00000268B6B7EEF0>>
# Traceback (most recent call last):
#   File "c:\Users\PC\Documents\GitHub\CS464_ML_Project\venv\lib\site-packages\ipykernel\ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# {'stft_db': array([[  8.279913  , -22.848013  ,   2.7390857 , ...,  -4.8315883 ,
#          -0.5552592 ,  -0.40884867],
#        [ 12.51931   ,  13.182785  ,  16.3331    , ...,  -0.07186656,
#           8.221512  ,  11.59392   ],
#        [ 20.513784  ,  22.806252  ,   1.2922056 , ...,  -1.1368241 ,
#          11.856032  ,  16.015114  ],
#        ...,
#        [-33.62595   , -33.62595   , -33.62595   , ..., -33.62595   ,
#         -33.62595   , -33.62595   ],
#        [-33.62595   , -33.62595   , -33.62595   , ..., -33.62595   ,
#         -33.62595   , -33.62595   ],
#        [-33.62595   , -33.62595   , -33.62595   , ..., -33.62595   ,
#         -33.62595   , -33.62595   ]], dtype=float32), 'spectral_rolloff': array([6513.79394531, 6707.59277344, 6987.52441406, ..., 6524.56054688,
#        6266.16210938, 5953.93066406]), 'zcr': array([[0.06005859, 0.09277344, 0.11376953, ..., 0.1796875 , 0.14453125,
#         0.08789062]]), 'chroma': array([[0.35812885, 0.5844225 , 0.3431106 , ..., 0.05782335, 0.10968778,
#         0.2829462 ],
#        [0.3725428 , 0.63809294, 0.5353896 , ..., 0.15076496, 0.24486527,
#         0.49940053],
#        [0.38778466, 0.49329916, 0.18880714, ..., 0.04940316, 0.1570142 ,
#         0.42548025],
#        ...,
#        [0.23791416, 0.32055938, 0.20629826, ..., 0.04807449, 0.22415026,
#         0.5124429 ],
#        [0.3049774 , 0.45864397, 0.28069708, ..., 0.10690378, 0.15842044,
#         0.36839205],
#        [0.36977938, 0.5936434 , 0.30992258, ..., 0.05903568, 0.07308657,
#         0.22698839]], dtype=float32), 'mfccs': array([[-71.22246  ,  -9.721093 ,   1.0670358, ..., -18.615978 ,
#          35.523075 ,  27.264627 ],
#        [ 70.143906 ,  64.17062  ,  64.26823  , ...,  61.19297  ,
#          77.179    ,  84.10733  ],
#        [ 21.382023 ,  22.773224 ,  25.61716  , ...,   1.2267262,
#           8.812157 ,  13.721062 ],
#        ...,
#        [  7.0454397,   7.121135 ,   5.652212 , ...,  14.952435 ,
#           8.474899 ,   8.840688 ],
#        [ 10.521723 ,  14.134985 ,  18.315187 , ...,   7.6968794,
#           1.780884 ,  -2.0983274],
#        [  5.420515 ,   6.393669 ,   6.744012 , ...,  16.744251 ,
#          12.158291 ,   8.570974 ]], dtype=float32), 'rms': array([[0.21523355, 0.26088154, 0.29351997, ..., 0.26089028, 0.2519393 ,
#         0.23104681]], dtype=float32), 'spectral_centroid': array([[2685.19790639, 2766.24405928, 2853.68919039, ..., 3233.27764791,
#         2750.34904805, 2517.47530122]]), 'file_name': '100_Paramparça.mp3', 'label': 0}
